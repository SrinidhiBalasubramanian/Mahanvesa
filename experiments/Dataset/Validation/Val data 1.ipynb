# %%
cd /content/drive/MyDrive/GenAI Project/
# Out:
# /content/drive/MyDrive/GenAI Project

# %%
import json

with open('Initial Experiments/mahabharata.json', 'r') as f:
    itihasa_data = json.load(f)

# %%
volumes = itihasa_data.keys()
final_data = {}
parva = 0
for i, vol in enumerate(volumes):
  for upaparva in itihasa_data[vol]:
    chapter = upaparva['chapter']
    if 'O' in chapter:
      chapter = chapter.replace('O', '0')
    if int(chapter) == 1:
      parva += 1
    print(f"{vol} : {chapter} : {upaparva['description']} :{len(upaparva['sn'])}")
    final_data[f"{parva}.{chapter}"] = " \n".join(upaparva['en'])
# Out:
# vol-i : 1 : Contents of subject :225
# vol-i : 2 : Brief introduction to the story of Mahabharata :337
# vol-i : 3 : Curse of Janamejaya by Sarama, Story of the Aruni, Upamanyu, Veda and Uttanka :177
# vol-i : 4 : Introduction of the story :11
# vol-i : 5 : Dialogue between Puloma and Agni :31
# vol-i : 6 : Birth of Chyavana, Bhrigu's curse on Agni :13
# vol-i : 7 : Agni freed from curse :26
# vol-i : 8 : Story of Ruru :24
# vol-i : 9 : Story of Ruru :23
# vol-i : 10 : Dialogue between Ruru and Dundubha :8
# vol-i : 11 : Story of Dundubha :18
# vol-i : 12 :  :6
# vol-i : 13 : Conference between Jaratkaru and manes :30
# vol-i : 14 : Jaratkaru's marriage with Vasuki's sister :7
# vol-i : 15 : Curse of snakes by mother Kadru :11
# vol-i : 16 : Story of the origin of snakes :22
# vol-i : 17 :  :11
# vol-i : 18 : Story of the churning the ocean :44
# vol-i : 19 : Churning the ocean :31
# vol-i : 20 : Curse of Kadru's sons :14
# vol-i : 21 : Description of the ocean :18
# ...

# %%
len(final_data)
# Out:
# 2108

# %%
with open('final_data.json', 'w') as f:
    json.dump(final_data, f, indent=4)

# %%
# !pip install sentence-transformers faiss-cpu tqdm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 57.4 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
import faiss
import pickle
from tqdm import tqdm

# %%
model = SentenceTransformer("sentence-transformers/multi-qa-mpnet-base-dot-v1")

doc_ids = list(final_data.keys())
texts = list(final_data.values())

# Batch encode for efficiency
embeddings = model.encode(texts, batch_size=32, show_progress_bar=True, convert_to_numpy=True)

np.save("Retrieval Experiments/embeddings_multi_mp.npy", embeddings)
with open("Retrieval Experiments/doc_ids.pkl", "wb") as f:
    pickle.dump(doc_ids, f)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/66 [00:00<?, ?it/s]

# %% [markdown]
# ### Questions

# %%
mahabharata_questions = {
    "1.1": {
        "chapter_title": "The book's premise, a brief list of most of the topics discussed in the book, and the glory of its readers",
        "questions": [
            "What is the main premise and scope of the Mahabharata as described in its introduction?",
            "Which topics are briefly listed or summarized at the start of the Mahabharata?",
            "What glories or benefits are said to come from reading or listening to the Mahabharata?"
        ]
    },
    "1.2": {
        "chapter_title": "Description of Samantpanchak region, evidence of Akshauhini army, collection of festivals mentioned in Mahabharata and their brief topics and results of listening and reading Mahabharata.",
        "questions": [
            "What is the significance of the Samantpanchak region in the Mahabharata?",
            "How is the Akshauhini army described or enumerated in the Mahabharata?",
            "Which festivals are mentioned in the Mahabharata and what are their meanings or outcomes?",
            "What are the stated benefits of reading or hearing the Mahabharata in this section?"
        ]
    },
    "1.3": {
        "chapter_title": "Saramaka's curse on Janamejaya, Janamejaya's selection of the priest of Somashrava, Aruni, Upamanyu, Vedas and devotion to Uttanka's Guru and encouragement to Janamejaya for Uttanka's Sarpayajna.",
        "questions": [
            "Why did Sage Saramaka curse King Janamejaya?",
            "How did Janamejaya choose Somashrava as his priest for the serpent sacrifice?",
            "What is the story of Aruni, Upamanyu, and their devotion to their Guru Uttanka?",
            "How did Uttanka inspire Janamejaya to perform the Sarpayajna (snake sacrifice)?"
        ]
    },
    "1.5": {
        "chapter_title": "Arrival of demon Puloma at Bhrigu's ashram and his conversation with Agnidev",
        "questions": [
            "What happened when the demon Puloma arrived at Sage Bhrigu’s ashram?",
            "What conversation took place between Puloma and the fire god Agni?"
        ]
    },
    "1.6": {
        "chapter_title": "Birth of Maharshi Chyavana, burning of demon Puloma by his brilliance and cursing of fire god Bhriguka",
        "questions": [
            "How was Maharshi Chyavana born?",
            "How did Chyavana destroy the demon Puloma?",
            "Why did Bhrigu curse the fire god Agni, and what was the outcome?"
        ]
    },
    "1.7": {
        "chapter_title": "Angered by the curse, Agnidev disappears and Brahma appeases him by mitigating his curse.",
        "questions": [
            "Why did Agni disappear from the world after being cursed by Bhrigu?",
            "How did Lord Brahma pacify Agni and mitigate his curse?"
        ]
    },
    "1.8": {
        "chapter_title": "The birth of Pramadvara, his exchange of words with Ruru and his death from a snake bite before marriage.",
        "questions": [
            "Who was Pramadvara, and how was she born?",
            "What conversations took place between Pramadvara and Ruru before their marriage?",
            "How did Pramadvara die, and what caused her death?"
        ]
    },
    "1.9": {
        "chapter_title": "Pramdvara's survival beyond half of Ruru's lifespan, her marriage to Ruru, Ruruka's determination to kill the snakes and the conversation between Ruru and Dundubha",
        "questions": [
            "How was Pramadvara revived to live half of Ruru’s lifespan?",
            "What happened after Ruru and Pramadvara’s marriage?",
            "Why did Ruru vow to kill all snakes?",
        ]
    },
    "1.10": {
        "chapter_title": "Ruru Muni and Dundubhaka Dialogue",
        "questions": [
            "What teachings did Dundubhaka share with Ruru?",
        ]
    }
}

mahabharata_questions.update({
    "1.11": {
        "chapter_title": "Dundubha's autobiography and his preaching of non-violence to Ruru",
        "questions": [
            "What is the story of Dundubha’s past as revealed in his autobiography?",
            "What lessons of non-violence did Dundubha impart to Ruru?",
            "How did Dundubha’s own life experiences influence his teachings to Ruru?"
        ]
    },
    "1.12": {
        "chapter_title": "Ruru's curiosity about Janamejaya's snake charmer and his father's satisfaction of it",
        "questions": [
            "Why was Ruru curious about Janamejaya’s snake charmer?",
            "How did Ruru’s father respond to or satisfy his curiosity?",
            "What was the significance of the snake charmer in Janamejaya’s story?"
        ]
    },
    "1.13": {
        "chapter_title": "Jaratkaruka being willing to marry at the request of his ancestors",
        "questions": [
            "Why did Jaratkaru agree to marry at the request of his ancestors?",
            "What was the background or reason behind Jaratkaru’s ancestors asking him to marry?",
            "How did Jaratkaru’s marriage fulfill his ancestors’ wishes?"
        ]
    },
    "1.14": {
        "chapter_title": "Jaratkaru takes the hand of Vasuki's sister",
        "questions": [
            "How did Jaratkaru come to marry Vasuki’s sister?",
            "What conditions or circumstances led to the union between Jaratkaru and Vasuki’s sister?",
            "What is the significance of Jaratkaru’s marriage to Vasuki’s sister in the Mahabharata?"
        ]
    },
    "1.23": {
        "chapter_title": "Defeated Vinata becomes Kadra's slave, the origin of Garuda and his praise by the gods",
        "questions": [
            "How did Vinata become Kadru’s slave?",
            "What is the origin story of Garuda according to the Mahabharata?",
            "Why did the gods praise Garuda after his birth?",
            "What was the relationship between Vinata and Kadru in this episode?"
        ]
    },
    "1.24": {
        "chapter_title": "Garuda's shrinking of his brilliance and body and Aruna's position on the chariot of the Sun to pacify the intense brilliance of Surya caused by his anger.",
        "questions": [
            "Why did Garuda reduce his brilliance and size?",
            "How did Aruna come to occupy his place as the charioteer of the Sun?",
            "What caused Surya’s intense brilliance and anger, and how was it pacified?",
            "What connection exists between Garuda, Aruna, and the Sun in this story?"
        ]
    },
    "1.25": {
        "chapter_title": "Kadru praises Lord Indra for saving a snake that had fainted due to the heat of the sun.",
        "questions": [
            "Why did Kadru praise Lord Indra in this section?",
            "How did Indra save the snake that had fainted from the sun’s heat?",
        ]
    },
    "1.26": {
        "chapter_title": "The serpents were pleased by the rain caused by Indra.",
        "questions": [
            "How did Indra cause rain that pleased the serpents?",
            "What events led to the serpents’ happiness after the rain?",
        ]
    },
    "1.27": {
        "chapter_title": "Description of the beautiful forest of Ramaniyak Island and Garuda's serpent pose to free him from slavery.",
        "questions": [
            "What is described about the forest of Ramaniyak Island?",
            "How did Garuda plan to free himself from slavery to Kadru?",
            "What role did the serpents play in Garuda’s attempt to gain freedom?",
            "How is the beauty of Ramaniyak Island portrayed in the Mahabharata?"
        ]
    },
    "1.28": {
        "chapter_title": "Garuda going for the nectar and eating the Nishadas as per his mother's orders",
        "questions": [
            "Why did Garuda go in search of nectar (amrita)?",
            "Why did Garuda eat the Nishadas as instructed by his mother?",
            "What challenges did Garuda face on his journey for the nectar?",
        ]
    }
})

mahabharata_questions.update({
    "1.29": {
        "chapter_title": "Kashyapa tells Garuda the story of the elephant and the tortoise's previous births, Garuda catches them and takes them to the branch of a divine banyan tree, and the branch breaks.",
        "questions": [
            "What story did Kashyapa tell Garuda about the previous births of the elephant and the tortoise?",
            "How did Garuda capture the elephant and the tortoise?",
        ]
    },
    "1.30": {
        "chapter_title": "Garuda meeting Kashyap, on his request the Valakhilyas leaving the branch for penance and Garuda leaving that branch on a deserted mountain",
        "questions": [
            "What happened when Garuda met Kashyapa after the banyan branch broke?",
            "Why did Kashyapa request the Valakhilyas to leave the branch for penance?",
        ]
    },
    "1.31": {
        "chapter_title": "Origin of Arun-Garuda due to Indra's insult to Valakhilyas and their penance.",
        "questions": [
            "How did Indra insult the Valakhilya sages?",
            "What penance did the Valakhilyas perform after being insulted by Indra?",
        ]
    },
    "1.32": {
        "chapter_title": "Garuda's battle with the gods and their defeat",
        "questions": [
            "Why did Garuda engage in battle with the gods?",
            "What was the outcome of Garuda’s battle against the gods?",
            "Which gods fought against Garuda, and how were they defeated?",
        ]
    },
    "1.33": {
        "chapter_title": "Garuda's return with the nectar, receiving a boon from Lord Vishnu on the way and being struck by Indra's thunderbolt.",
        "questions": [
            "What happened when Garuda returned with the nectar (amrita)?",
            "What boon did Lord Vishnu grant to Garuda on his journey?",
            "Why did Indra strike Garuda with his thunderbolt, and what was the result?",
        ]
    },
    "1.34": {
        "chapter_title": "The friendship between Indra and Garuda, Garuda's arrival with the nectar to the snakes and the release of Vinata from slavery, and Indra's abduction of the nectar",
        "questions": [
            "How did Indra and Garuda become friends after their conflict?",
            "What did Garuda do with the nectar when he arrived among the snakes?",
            "How was Vinata released from slavery through Garuda’s actions?",
        ]
    },
    "1.36": {
        "chapter_title": "Sheshnag's penance, getting a boon from Brahmaji and holding the earth on his head.",
        "questions": [
            "What boon did Brahma grant to Sheshnag as a result of his penance?",
            "How did Sheshnag come to hold the earth upon his head?",
        ]
    },
    "1.37": {
        "chapter_title": "To escape from the curse of their mother, the serpents like Vasuki consulted each other.",
        "questions": [
            "Why were the serpents cursed by their mother?",
            "How did Vasuki and the other serpents plan to escape from the curse?",
        ]
    },
    "1.38": {
        "chapter_title": "Vasuki's sister Jaratkaruka decides to marry Jaratkaru Muni",
        "questions": [
            "Why did Vasuki’s sister Jaratkaruka decide to marry Jaratkaru Muni?",
            "What circumstances led to Jaratkaruka’s decision to marry the sage?",
        ]
    },
    "1.39": {
        "chapter_title": "At the behest of Brahma, Vasukika tries to get his sister married to Jaratkaru Muni.",
        "questions": [
            "What did Brahma instruct Vasukika to do regarding his sister’s marriage?",
            "How did Vasukika approach Jaratkaru Muni for the marriage proposal?",
        ]
    },
    "1.40": {
        "chapter_title": "Jaratkara's penance, the story of King Parikshit and the provocation of Krushakasringi, who was distressed by the king placing a dead snake on the sage's shoulder.",
        "questions": [
            "What penance did Jaratkaru perform in this section?",
            "What incident led King Parikshit to place a dead snake on the sage’s shoulder?",
            "Why was Krushakaśṛṅgi distressed by the king’s act?",
        ]
    },
    "1.41": {
        "chapter_title": "Shringi Rishi cursing King Parikshit and Shamika pacifying his son and saying that the curse is unfair.",
        "questions": [
            "Why did Shringi Rishi curse King Parikshit?",
            "How did Sage Shamika react to his son Shringi’s curse?",
            "Why did Shamika believe that the curse on King Parikshit was unfair?",
        ]
    }
})

mahabharata_questions.update({
    "1.42": {
        "chapter_title": "Shamika's counselling to his son and sending Gaurmukha to King Parikshit, the king's arrangements for self-defence and the conversation between Takshaka snake and Kashyap.",
        "questions": [
            "What advice did Sage Shamika give his son after he cursed King Parikshit?",
            "Why did Shamika send Gaurmukha to deliver a message to King Parikshit?",
            "What preparations did King Parikshit make to protect himself from Takshaka’s curse?",
        ]
    },
    "1.43": {
        "chapter_title": "Returning Takshaka's money to Kashyapa and then approaching King Parikshit by deceit and biting him",
        "questions": [
            "Why did Takshaka offer money to Kashyapa, and why did Kashyapa return it?",
            "How did Takshaka approach King Parikshit through deceit?",
            "How did Takshaka finally kill King Parikshit?",
        ]
    },
    "1.44": {
        "chapter_title": "Janamejaya's coronation and marriage",
        "questions": [
            "How did Janamejaya’s coronation ceremony take place?",
            "Whom did Janamejaya marry, and under what circumstances?",
        ]
    },
    "1.45": {
        "chapter_title": "Jaratkaru's vision of his ancestors and conversation with them",
        "questions": [
            "What did Jaratkaru see in his vision of his ancestors?",
            "What conversation took place between Jaratkaru and his forefathers?",
            "Why were Jaratkaru’s ancestors in distress in his vision?",
        ]
    },
    "1.46": {
        "chapter_title": "Jaratkaruka agrees to marry with a condition and brings the daughter of the serpent king Vasukika named Jaratkaru.",
        "questions": [
            "What condition did Jaratkaru set before agreeing to marry?",
            "How did Jaratkaru meet and marry the daughter of Vasukika?",
            "Why was Vasukika’s daughter also named Jaratkaru?",
        ]
    },
    "1.47": {
        "chapter_title": "Marriage of the sage Jaratkaru with the serpent girl, the serpent girl serving her husband and the husband abandoning her and going for penance.",
        "questions": [
            "How was the marriage between Jaratkaru and the serpent girl solemnized?",
            "How did the serpent girl serve her husband with devotion?",
            "Why did Sage Jaratkaru abandon his wife after marriage?",
            "Where did Jaratkaru go to perform penance after leaving his wife?"
        ]
    },
    "1.48": {
        "chapter_title": "Vasuki Naga's worries, his relief by his sister and the birth and education of Aastika",
        "questions": [
            "Why was Vasuki Naga troubled after Jaratkaru left his sister?",
            "How did Vasuki’s sister console or relieve her brother’s worries?",
            "How was Aastika born, and who were his parents?",
        ]
    },
    "1.49": {
        "chapter_title": "Description of the righteous conduct and noble qualities of King Parikshit, the king's hunting and his disdain of the sage Shamika",
        "questions": [
            "What qualities of righteousness and virtue did King Parikshit possess?",
            "What happened during King Parikshit’s hunting expedition?",
            "Why did King Parikshit insult or disdain the sage Shamika?",
        ]
    },
    "1.50": {
        "chapter_title": "Shringi Rishi's curse on Parikshit, Takshak's stinging of Parikshit after returning Kashyap, and Janamejaya's vow to take revenge on Takshak after hearing the story of his father's death.",
        "questions": [
            "Why did Shringi Rishi curse King Parikshit?",
            "How did Takshaka fulfill the curse by killing King Parikshit?",
            "Why did Kashyapa return after attempting to save Parikshit?",
            "How did Janamejaya react upon learning of his father’s death, and what vow did he make?"
        ]
    },
    "1.56": {
        "chapter_title": "King getting ready to give a boon to Aastik, Takshak Naga being worried and Aastik asking for a boon.",
        "questions": [
            "Why did the king decide to grant a boon to Aastika?",
            "Why was Takshaka Naga worried during the serpent sacrifice?",
            "What boon did Aastika request from the king?",
        ]
    },
    "1.57": {
        "chapter_title": "Names of the chief snakes burnt in the serpent sacrifice",
        "questions": [
            "Which were the chief snakes that were burnt in Janamejaya’s serpent sacrifice?",
            "How are the names of the serpents listed or described in this chapter?",
        ]
    },
})

mahabharata_questions.update({
    "1.60": {
        "chapter_title": "Arrival of Vyasji in the Yagya of Janmejaya, felicitation and with the request of the king, Vyasji asks Vaishampayanji to narrate the story of Mahabharata.",
        "questions": [
            "When did Vyasa arrive at Janamejaya’s Yajna?",
            "Who requested Vaishampayana to narrate the Mahabharata?",
            "In which episode does Vyasa ask Vaishampayana to tell the story of the Mahabharata?",
            "Where in the Mahabharata is the narration of the epic formally begun?",
            "Who initiated the recitation of the Mahabharata during Janamejaya’s sacrifice?"
        ]
    },
    "1.68": {
        "chapter_title": "Description of King Dushyant's amazing power and ability to rule the kingdom.",
        "questions": [
            "Which section describes King Dushyanta’s power and governance abilities?",
            "How is King Dushyanta’s rule and strength depicted in the Mahabharata?",
            "Where is Dushyanta’s administrative skill and valor mentioned?",
            "What attributes made King Dushyanta a capable ruler according to the text?"
        ]
    },
    "1.69": {
        "chapter_title": "Dushyanta goes hunting in the forest and kills various ferocious wild animals.",
        "questions": [
            "Where does King Dushyanta go hunting in the Mahabharata?",
            "Which chapter narrates Dushyanta’s hunting expedition in the forest?",
            "What animals does King Dushyanta hunt and kill?",
            "Which passage describes Dushyanta’s encounter with wild beasts?"
        ]
    },
    "1.70": {
        "chapter_title": "Description of Tapovan and Kanva's ashram and King Dushyant's entry into that ashram.",
        "questions": [
            "Which chapter describes Kanva’s ashram and its surroundings?",
            "When does King Dushyanta enter Sage Kanva’s hermitage?",
            "Where is the Tapovan described in connection with Dushyanta?",
            "Which scene introduces Dushyanta’s arrival at Kanva’s ashram?"
        ]
    },
    "1.71": {
        "chapter_title": "King Dushyant's conversation with Shakuntala, Shakuntala telling him the reason for her birth and in the same context Indra, worried by Vishwamitra's penance, sends Menaka to break the sage's penance.",
        "questions": [
            "Where does Dushyanta first meet and converse with Shakuntala?",
            "In which part does Shakuntala narrate the story of her birth?",
            "Which episode describes Indra sending Menaka to disturb Vishwamitra’s penance?",
            "How are Shakuntala’s origins connected to Vishwamitra and Menaka in the Mahabharata?"
        ]
    },
    "1.72": {
        "chapter_title": "Meeting of Menaka and Vishwamitra, birth of the girl, her protection by the Shakunt birds and Kanva bringing her to his ashram and raising her by naming her Shakuntala.",
        "questions": [
            "Which chapter narrates the meeting of Menaka and Vishwamitra?",
            "Where is the birth and rescue of the child Shakuntala described?",
            "Who raised Shakuntala after her birth, and how did she get her name?",
            "How did the Shakunta birds protect the infant Shakuntala?"
        ]
    },
    "1.73": {
        "chapter_title": "Gandharva marriage of Shakuntala and Dushyant and its approval by Maharishi Kanwake",
        "questions": [
            "Which section describes the Gandharva marriage between Shakuntala and Dushyanta?",
            "Who approved the marriage of Shakuntala and Dushyanta in the Mahabharata?",
            "What type of marriage took place between Shakuntala and Dushyanta?",
            "In which part is Kanva’s approval of Shakuntala’s marriage mentioned?"
        ]
    },
    "1.74": {
        "chapter_title": "Birth of Shakuntala's son, his amazing power, Shakuntala's visit to Dushyant along with her son, Dushyant-Shakuntala's dialogue, Shakuntala's Shuddhika support through Akashvani and Bharat's coronation.",
        "questions": [
            "Which chapter narrates the birth of Shakuntala’s son Bharata?",
            "Where does Shakuntala meet Dushyanta after giving birth to her son?",
            "In which episode does Akashvani confirm Shakuntala’s purity?",
            "Where is Bharata’s coronation described in the Mahabharata?",
            "How is Shakuntala’s confrontation with Dushyanta depicted?"
        ]
    },
    "1.118": {
        "chapter_title": "King Pandu kills a deer-like sage and receives a curse from her",
        "questions": [
            "Which section describes King Pandu accidentally killing a sage disguised as a deer?",
            "Who cursed King Pandu and why?",
            "Where is the origin of Pandu’s curse narrated?",
            "What event caused Pandu to renounce his royal duties?"
        ]
    },
    "1.119": {
        "chapter_title": "Panduka's repentance, determination to take sannyasa and entry into Vanaprastha Ashram with the request of his wives.",
        "questions": [
            "Which chapter describes King Pandu’s repentance for killing the sage?",
            "Where does Pandu renounce worldly life and take sannyasa?",
            "What role did Pandu’s wives play in his decision to enter the forest?",
            "Which episode marks Pandu’s entry into Vanaprastha Ashram?"
        ]
    },
    "1.121": {
        "chapter_title": "Narration of the birth of a son by his devoted wife Bhadra from the dead body - History of Vyushitashva",
        "questions": [
            "Which story in the Mahabharata describes Bhadra giving birth from the body of her dead husband?",
            "Who was Vyushitashva, and what was the miracle involving his wife Bhadra?",
            "Where is the tale of Bhadra and Vyushitashva mentioned?",
            "Which section recounts the miraculous birth narrated by Bhadra?"
        ]
    },
    "1.126": {
        "chapter_title": "The sages taking Kunti and the Pandavas to Hastinapur and handing them over to Bhishma and others.",
        "questions": [
            "Which episode narrates the return of Kunti and the Pandavas to Hastinapura?",
            "Who escorted the Pandavas and Kunti to Bhishma after Pandu’s death?",
            "Where does the Mahabharata describe the meeting between Bhishma and the Pandavas?",
            "What was Bhishma’s role in receiving Kunti and her sons?"
        ]
    },
    "1.127": {
        "chapter_title": "Cremation of the ashes of Pandu and Madri and offering of water to them by brothers",
        "questions": [
            "Where is the funeral of Pandu and Madri described?",
            "Which section mentions the Pandavas performing rites for their parents?",
            "How did the brothers offer water and tribute to Pandu and Madri?",
            "What significance does this ritual hold in the Pandavas’ early life?"
        ]
    },
    "1.128": {
        "chapter_title": "The childhood games of the Pandavas and Dhritarashtra's sons, Duryodhana feeding poison to Bhimasena and pushing him into the Ganga, and Bhima reaching the Nagaloka and drinking the divine nectar from eight ponds.",
        "questions": [
            "Which chapter describes the childhood of the Pandavas and Kauravas?",
            "Where is Duryodhana’s attempt to poison Bhima mentioned?",
            "What happened to Bhima after he was pushed into the Ganga?",
            "Which section narrates Bhima’s journey to Nagaloka and his drinking of divine nectar?"
        ]
    },
    "1.129": {
        "chapter_title": "Kunti etc.'s worries due to Bhimsen's absence, Bhimsen's arrival from Nagalok and Duryodhana's ill intentions towards him.",
        "questions": [
            "Which section describes Kunti’s anxiety over Bhima’s disappearance?",
            "Where does Bhima return from the Nagaloka after gaining strength?",
            "How did Duryodhana react after Bhima’s return from the Nagas’ realm?",
            "Which chapter continues the conflict between Bhima and Duryodhana after Bhima’s return?"
        ]
    }
})

mahabharata_questions.update({
    "1.147": {
        "chapter_title": "The construction of a tunnel in the Lakhshagriha by the miner sent by Vidura",
        "questions": [
            "Who built the secret tunnel beneath the Lakshagriha?",
            "Which miner did Vidura send to construct a tunnel for the Pandavas?",
            "Where in the Mahabharata is the tunnel under the house of lac described?",
            "How did Vidura help the Pandavas prepare for their escape from the Lakshagriha?"
        ]
    },
    "1.148": {
        "chapter_title": "Burning of the Lakhshagriha and the escape of the Pandavas through the tunnel",
        "questions": [
            "Which chapter describes the burning of the house of lac (Lakshagriha)?",
            "How did the Pandavas escape from the burning Lakshagriha?",
            "Where is the Pandavas’ night-time escape through the tunnel mentioned?",
            "Who set fire to the Lakshagriha, and what was the outcome?"
        ]
    },
    "1.149": {
        "chapter_title": "The sailor sent by Vidurji to take the Pandavas across the Ganges.",
        "questions": [
            "Who arranged for the Pandavas to cross the Ganga after escaping the Lakshagriha?",
            "Which sailor helped the Pandavas flee across the river?",
            "Where is Vidura’s assistance in ferrying the Pandavas across the Ganges described?",
            "What role did the boatman play in helping the Pandavas escape?"
        ]
    },
    "1.150": {
        "chapter_title": "Condolence and water offering for the Pandavas by Dhritarashtra etc. and Pandavas' entry into the forest.",
        "questions": [
            "Which chapter narrates Dhritarashtra’s mourning and offering of water for the supposedly dead Pandavas?",
            "Where is the ritual condolence for the Pandavas mentioned?",
            "How did Dhritarashtra and others react to the news of the Pandavas’ death in the fire?",
            "Which passage marks the Pandavas’ entry into the forest after the Lakshagriha incident?"
        ]
    },
    "1.151": {
        "chapter_title": "Bhimasena bringing water for mother Kunti, Bhima's sadness on seeing his mother and brothers sleeping on the ground and his anger towards Duryodhana",
        "questions": [
            "Which section describes Bhima’s sorrow seeing his family suffer in the forest?",
            "Where is Bhimasena shown bringing water for Kunti?",
            "How does Bhima react to Kunti and his brothers sleeping on the bare ground?",
            "In which episode does Bhima express anger towards Duryodhana after their escape?"
        ]
    },
    "1.152": {
        "chapter_title": "Hidimba the demoness arrives at the Pandavas on the orders of Hidimba and her conversation with Bhimasena",
        "questions": [
            "Where does Hidimbi first encounter Bhima and the Pandavas?",
            "Which chapter introduces the demoness Hidimba and her dialogue with Bhima?",
            "How is the first meeting between Bhima and Hidimba described?",
            "Who sends Hidimbi to meet the Pandavas and why?"
        ]
    },
    "1.153": {
        "chapter_title": "Hidimba's arrival, Hidimbaka being frightened by him and the battle between Bhima and Hidimbasura",
        "questions": [
            "Which section narrates the battle between Bhima and the demon Hidimba?",
            "Where is Hidimbasura’s fear and confrontation with Bhimasena mentioned?",
            "Who fights Hidimba in the Mahabharata and what happens in that combat?",
            "Which chapter depicts Bhima’s combat with the rakshasa Hidimbasura?"
        ]
    },
    "1.154": {
        "chapter_title": "Hidimba's expression of his feelings to Kunti etc and the killing of Hidimbasura by Bhimasena.",
        "questions": [
            "In which episode does Bhima slay Hidimbasura?",
            "Where does Hidimba express her affection toward Bhima and Kunti?",
            "Who kills the rakshasa Hidimba and under what circumstances?",
            "Which passage describes Hidimba’s confession of feelings before Bhima kills Hidimbasura?"
        ]
    },
    "1.155": {
        "chapter_title": "Yudhishthira's stopping Bhimsen from killing Hidimba, Hidimba's prayer for Bhimsen, the meeting of Bhimsen and Hidimba and the origin of Ghatotkacha.",
        "questions": [
            "Which chapter tells of Yudhishthira stopping Bhima from killing Hidimba?",
            "Where is the story of Bhima and Hidimbi’s union and the birth of Ghatotkacha narrated?",
            "Who was Ghatotkacha and how was he born?",
            "Which section contains Hidimbi’s prayer to Bhima before their marriage?"
        ]
    },
    "1.156": {
        "chapter_title": "The Pandavas meet Vyasa and enter the city of Ekachakra.",
        "questions": [
            "Where do the Pandavas meet Vyasa after escaping the forest?",
            "Which chapter marks the Pandavas’ arrival at Ekachakra?",
            "Who guides the Pandavas to settle temporarily in Ekachakra?",
            "Where is the meeting between Vyasa and the Pandavas described after the Lakshagriha incident?"
        ]
    }
})

mahabharata_questions.update({
    "3.1": {
        "chapter_title": "The Pandavas' departure to the forest, their pursuit by the townspeople, their return at Yudhishthira's request, and the Pandavas' overnight stay at Praman-Kotirtha.",
        "questions": [
            "Where is the Pandavas’ departure to the forest described?",
            "Which chapter mentions the Pandavas staying overnight at Praman-Kotirtha?"
        ]
    },
    "3.2": {
        "chapter_title": "Conversation between the Brahmins and Shaunaka with Dharmaraja Yudhishthira on the demerits of wealth, the importance of hospitality and the means of welfare.",
        "questions": [
            "What discussion does Yudhishthira have with the Brahmins about wealth and hospitality?",
            "Which chapter records Shaunaka’s dialogue with Yudhishthira on dharma and welfare?"
        ]
    },
    "3.3": {
        "chapter_title": "Yudhishthira worships Lord Surya for food and receives the Akshaya Patra from him.",
        "questions": [
            "Where does Yudhishthira obtain the Akshaya Patra from Surya?",
            "Which section describes Yudhishthira’s prayer to Lord Surya for sustenance?"
        ]
    },
    "3.4": {
        "chapter_title": "Vidura gives beneficial advice to Dhritarashtra and Dhritarashtra leaves the palace in anger.",
        "questions": [
            "Which chapter describes Vidura advising Dhritarashtra?",
            "Where does Dhritarashtra become angry and leave the palace after Vidura’s counsel?"
        ]
    },
    "3.5": {
        "chapter_title": "The Pandavas enter Kamyakavana and Vidura goes there to meet and talk to them.",
        "questions": [
            "Where do the Pandavas enter Kamyakavana during their exile?",
            "Which chapter narrates Vidura’s meeting with the Pandavas in Kamyakavana?"
        ]
    },
    "3.6": {
        "chapter_title": "Dhritarashtra sends Sanjaya to summon Vidura from the forest and beg his forgiveness.",
        "questions": [
            "Who sends Sanjaya to bring Vidura back from the forest?",
            "In which chapter does Dhritarashtra ask for Vidura’s forgiveness?"
        ]
    },
    "3.7": {
        "chapter_title": "The advice of Duryodhana, Dushasan, Shakuni and Karna, their preparation to go to the forest to kill the Pandavas and Vyasji's arrival to stop them.",
        "questions": [
            "Where do Duryodhana and his allies plan to attack the Pandavas in the forest?",
            "Which chapter mentions Vyasa stopping Duryodhana from harming the Pandavas?"
        ]
    },
    "3.8": {
        "chapter_title": "Vyasa requests Dhritarashtra to stop Duryodhana's injustice.",
        "questions": [
            "Which section records Vyasa advising Dhritarashtra against Duryodhana’s injustice?",
            "Where does Vyasa intervene to protect the Pandavas from Duryodhana’s schemes?"
        ]
    },
    "3.9": {
        "chapter_title": "Vyasa's narration of the story of Surabhi and Indra and their kindness towards the Pandavas.",
        "questions": [
            "What is the story of Surabhi and Indra narrated by Vyasa?",
            "Where does Vyasa describe Surabhi and Indra showing kindness to the Pandavas?"
        ]
    },
    "3.10": {
        "chapter_title": "Vyasa's departure, Maitreya's request to Dhritarashtra and Duryodhana to be kind to the Pandavas, and his curse on Duryodhana after being angered by his rude behaviour.",
        "questions": [
            "Who curses Duryodhana for his arrogance towards Maitreya?",
            "Which chapter describes Maitreya advising Dhritarashtra to be kind to the Pandavas?"
        ]
    },
    "3.12": {
        "chapter_title": "Praise of Lord Krishna by Arjuna and Draupadi, Draupadi's description of the insult and sorrow done to her by Lord Krishna and assurance given to her by Lord Krishna, Arjuna and Dhristadyumna.",
        "questions": [
            "Which section records Draupadi lamenting her humiliation before Krishna?",
            "Where do Arjuna and Krishna assure Draupadi after her insult?"
        ]
    },
    "3.13": {
        "chapter_title": "Shri Krishna points out the faults of gambling and considers his absence as the reason for the calamity that befell the Pandavas.",
        "questions": [
            "Where does Krishna discuss the evils of gambling with the Pandavas?",
            "Which chapter mentions Krishna regretting his absence during the dice game?"
        ]
    },
    "3.14": {
        "chapter_title": "A brief description of Sri Krishna's battle with Shalva, who failed to arrive at the dice, and his destruction along with Saubha's aircraft.",
        "questions": [
            "Which chapter describes Krishna’s battle with Shalva and the destruction of Saubha?",
            "Where is Shalva’s defeat by Krishna narrated?"
        ]
    },
    "3.15": {
        "chapter_title": "Description of the defensive preparations for war in Dwaraka in the context of the detailed story of Saubha-destruction.",
        "questions": [
            "Where are Dwaraka’s war preparations against Shalva described?",
            "Which section narrates Krishna’s military preparations before the Saubha battle?"
        ]
    },
    "3.16": {
        "chapter_title": "The Yadav army resists the attack of Shalva's huge army, defeats Kshemavardi by Samba, kills Vegavan and kills Vivindhya demon by Charudeshna and Pradyumna assures the army.",
        "questions": [
            "Which chapter depicts the Yadava army fighting Shalva’s forces?",
            "Where is Pradyumna shown assuring the Yadava army in battle?"
        ]
    },
    "3.17": {
        "chapter_title": "Fierce battle between Pradyumna and Shalva",
        "questions": [
            "Which section narrates the duel between Pradyumna and Shalva?",
            "Where does Pradyumna fight Shalva in a fierce battle?"
        ]
    },
    "3.18": {
        "chapter_title": "Pradyumna's remorse at being carried unconscious from the battlefield by his charioteer and his rebuke to the charioteer for this.",
        "questions": [
            "Which chapter shows Pradyumna rebuking his charioteer for withdrawing him from battle?",
            "Where is Pradyumna’s remorse described after being carried from the field?"
        ]
    },
    "3.19": {
        "chapter_title": "Defeat of Shalva by Pradyumna",
        "questions": [
            "Where does Pradyumna defeat Shalva in combat?",
            "Which section records Shalva’s downfall at Pradyumna’s hands?"
        ]
    },
    "3.20": {
        "chapter_title": "The fierce battle between Sri Krishna and Shalva",
        "questions": [
            "Which chapter narrates the final battle between Krishna and Shalva?",
            "Where does Krishna destroy Shalva in direct combat?"
        ]
    },
    "3.27": {
        "chapter_title": "Draupadi's angry words to Yudhishthira to arouse his anger towards his enemy",
        "questions": [
            "Which section records Draupadi’s anger at Yudhishthira during exile?",
            "Where does Draupadi urge Yudhishthira to fight his enemies?"
        ]
    },
    "3.28": {
        "chapter_title": "Draupadi's narration of the conversation between Prahlad and Bali - an occasion for brilliance and forgiveness",
        "questions": [
            "Which chapter contains Draupadi’s narration of the dialogue between Prahlad and Bali?",
            "Where is the story of Prahlad and Bali used by Draupadi to teach forgiveness?"
        ]
    }
})

mahabharata_questions.update({
    "3.29": {
        "chapter_title": "Yudhishthira's condemnation of anger and special praise of forgiveness",
        "questions": [
            "Where does Yudhishthira discuss the dangers of anger and the virtue of forgiveness?",
            "Which section records Yudhishthira praising forgiveness as a supreme virtue?"
        ]
    },
    "3.30": {
        "chapter_title": "Draupadi, overcome with grief, casts aspersions on Yudhishthira's wisdom, righteousness and divine justice.",
        "questions": [
            "Where does Draupadi criticize Yudhishthira’s sense of dharma and justice?",
            "Which chapter describes Draupadi’s grief and reproach of Yudhishthira’s wisdom?"
        ]
    },
    "3.31": {
        "chapter_title": "Yudhishthira's solution to Draupadi's objection and the benefits of respecting God, religion and great men and the harm of disrespecting them.",
        "questions": [
            "Which section contains Yudhishthira’s response to Draupadi’s objections about dharma?",
            "Where does Yudhishthira explain the benefits of honoring God and sages?"
        ]
    },
    "3.32": {
        "chapter_title": "Draupadi's insistence on making efforts, considering them to be paramount",
        "questions": [
            "Where does Draupadi urge Yudhishthira to value effort over destiny?",
            "Which chapter records Draupadi emphasizing the importance of human endeavor?"
        ]
    },
    "3.33": {
        "chapter_title": "Praising Bhimasena's valour and encouraging Yudhishthira to wage war according to the Kshatriya Dharma",
        "questions": [
            "Which section praises Bhima’s valor and urges Yudhishthira to follow Kshatriya dharma?",
            "Where is Yudhishthira encouraged to take up arms against his enemies?"
        ]
    },
    "3.34": {
        "chapter_title": "Yudhishthira's declaration of staying true to his vow, speaking of Dharma and Niti (Nalopakhyana Parva)",
        "questions": [
            "Where does Yudhishthira reaffirm his vow to follow dharma in the forest?",
            "Which chapter introduces the Nalopakhyana Parva with teachings on dharma and conduct?"
        ]
    },
    "3.35": {
        "chapter_title": "The distressed Bhimasena encourages Yudhishthira to fight.",
        "questions": [
            "Where does Bhima urge Yudhishthira to fight despite their misfortunes?",
            "Which section shows Bhimasena expressing frustration at Yudhishthira’s patience?"
        ]
    },
    "3.36": {
        "chapter_title": "Yudhishthira's explanation to Bhimsen, Vyasji's arrival and imparting Pratismriti Vidya to Yudhishthira and Pandavas' return to Kamyakavan.",
        "questions": [
            "Which chapter records Vyasa teaching Pratismriti Vidya to Yudhishthira?",
            "Where does Vyasa meet the Pandavas and guide them before returning to Kamyakavana?"
        ]
    },
    "3.37": {
        "chapter_title": "Arjuna's visit to Indrakil mountain along with his brothers and meeting Indra (Kairata Parva)",
        "questions": [
            "Where does Arjuna travel to Indrakil mountain and meet Indra?",
            "Which section begins the Kairata Parva and Arjuna’s quest for divine weapons?"
        ]
    },
    "3.38": {
        "chapter_title": "Arjuna's intense penance and the sages' conversation with Lord Shankar about it",
        "questions": [
            "Which chapter describes Arjuna’s severe penance to please Lord Shiva?",
            "Where do sages discuss Arjuna’s tapasya with Lord Shankar?"
        ]
    },
    "3.39": {
        "chapter_title": "The Arjuna's hymn to Shiva",
        "questions": [
            "Where is Arjuna’s stotra or hymn in praise of Lord Shiva found?",
            "Which section narrates Arjuna’s prayer to Lord Shiva before receiving a boon?"
        ]
    },
    "3.40": {
        "chapter_title": "Lord Shankar gave a boon to Arjun and left for his abode.",
        "questions": [
            "Which chapter narrates Shiva granting a boon to Arjuna?",
            "Where does Lord Shankar bless Arjuna with divine weapons and depart?"
        ]
    },
    "3.41": {
        "chapter_title": "Arrival of Dikpalas to Arjun and giving him divine weapons and Indra ordering him to go to heaven (Indraloka Abhigamana Parva).",
        "questions": [
            "Which section describes the Dikpalas gifting divine weapons to Arjuna?",
            "Where is Arjuna instructed by Indra to ascend to heaven?"
        ]
    }
})

mahabharata_questions.update({
    "3.42": {
        "chapter_title": "Arjuna departs from the Himalayas and goes to heaven with Matali.",
        "questions": [
            "Where does Arjuna ascend to heaven with Matali as his charioteer?",
            "Which chapter describes Arjuna’s journey from the Himalayas to Indraloka?"
        ]
    },
    "3.43": {
        "chapter_title": "Arjun's visit to Devraj Indra and sending Indra and Kumari to Kundinpur.",
        "questions": [
            "Where is Arjuna’s meeting with Devraj Indra described?",
            "Which chapter mentions Indra sending a maiden to Kundinpur?"
        ]
    },
    "3.44": {
        "chapter_title": "Teaching Arjuna about weapons and swords in Indraloka",
        "questions": [
            "Which section describes Arjuna learning divine weapons in Indraloka?",
            "Where does Indra instruct Arjuna in celestial warfare?"
        ]
    },
    "3.45": {
        "chapter_title": "Conversation between Chitrasena and Urvashika",
        "questions": [
            "Where is the dialogue between Chitrasena and Urvashi found?",
            "Which chapter features Chitrasena’s discussion with Urvashi in heaven?"
        ]
    },
    "3.46": {
        "chapter_title": "Urvashi, driven by sexual desire, goes to Arjuna and returns cursing him when he rejects her.",
        "questions": [
            "Where does Urvashi approach Arjuna with desire and curse him upon rejection?",
            "Which chapter narrates Urvashi’s curse making Arjuna live as a eunuch?"
        ]
    },
    "3.47": {
        "chapter_title": "Lomash Muni should meet Indra and Arjuna in heaven and take their message to Kamyakavan.",
        "questions": [
            "Which section narrates Lomasha meeting Arjuna and Indra in heaven?",
            "Where does Lomasha carry Indra’s message to the Pandavas in Kamyakavana?"
        ]
    },
    "3.48": {
        "chapter_title": "A distressed Dhritarashtra expresses concern for his sons in front of Sanjaya.",
        "questions": [
            "Which chapter shows Dhritarashtra expressing worry for his sons?",
            "Where does Dhritarashtra confide his fears to Sanjaya?"
        ]
    },
    "3.49": {
        "chapter_title": "Sanjaya's approval of Dhritarashtra's pleas and Dhritarashtra's anger",
        "questions": [
            "Which section records Dhritarashtra’s anger during his discussion with Sanjaya?",
            "Where does Sanjaya attempt to calm the worried Dhritarashtra?"
        ]
    },
    "3.50": {
        "chapter_title": "The Pandavas' diet in the forest",
        "questions": [
            "Where is the description of the Pandavas’ diet during their forest exile?",
            "Which chapter mentions what food the Pandavas ate while in the forest?"
        ]
    },
    "3.51": {
        "chapter_title": "Sanjaya narrates to Dhritarashtra the story of the vow made by Sri Krishna and others to kill Duryodhana and others.",
        "questions": [
            "Where does Sanjaya tell Dhritarashtra about Krishna’s vow to destroy Duryodhana?",
            "Which chapter contains the account of Krishna’s oath for the Pandavas’ revenge?"
        ]
    },
    "3.52": {
        "chapter_title": "Bhimsen - Yudhishthir dialogue, arrival of Brihadashva and introduction of Nalopakhyan by Brihadashva on Yudhishthira's request.",
        "questions": [
            "Where does Brihadashva narrate the story of Nala to Yudhishthira?",
            "Which chapter describes Brihadashva meeting the Pandavas and beginning the Nalopakhyana?"
        ]
    },
    "3.106": {
        "chapter_title": "King Sagara performs penance for a child and receives a boon from Lord Shiva",
        "questions": [
            "Where is King Sagara’s penance to obtain children described?",
            "Which chapter narrates Lord Shiva granting a boon to King Sagara?"
        ]
    },
    "3.107": {
        "chapter_title": "The birth of Sagara's sons, the burning of sixty thousand sons of Sagara by Kapila's anger, the abandonment of confusion, the fulfillment of Sagara's wish through the efforts of Anshuman, the attainment of the kingdom by Dilipa from Anshumana and by Bhagiratha from Dilipa.",
        "questions": [
            "Which section narrates the burning of King Sagara’s sixty thousand sons by Sage Kapila?",
            "Where is the lineage from Sagara to Bhagiratha described in the Mahabharata?"
        ]
    },
    "3.108": {
        "chapter_title": "Bhagiratha's penance in the Himalayas by pleasing Ganga and obtaining a boon from her.",
        "questions": [
            "Which chapter describes Bhagiratha’s penance to bring the Ganga to earth?",
            "Where does Ganga grant Bhagiratha the boon to descend from heaven?"
        ]
    },
    "3.109": {
        "chapter_title": "Description of Ganga ji descending on earth and filling the ocean with water and the salvation of Sagarputras.",
        "questions": [
            "Where is the descent of Ganga from heaven to earth narrated?",
            "Which chapter describes the salvation of the sons of Sagara through Ganga’s descent?"
        ]
    }
})

mahabharata_questions.update({
    "3.110": {
        "chapter_title": "The greatness of Nanda and Kaushikika, the anecdote of Rishyashringa Munika and the efforts of King Lomapada to bring them into his kingdom.",
        "questions": [
            "Which chapter narrates King Lomapada’s efforts to bring Rishyashringa to his kingdom?",
            "Where is the story of Rishyashringa and the greatness of Nanda and Kaushiki described?"
        ]
    },
    "3.111": {
        "chapter_title": "The prostitute seduces Rishisringa and Vibhandaka Munika comes to the ashram and asks the reason for his worry about his son.",
        "questions": [
            "Where does the prostitute seduce Rishyashringa to lure him away from his ashram?",
            "Which chapter shows Vibhandaka questioning the cause of his concern for Rishyashringa?"
        ]
    },
    "3.112": {
        "chapter_title": "Rishyashringa's description of the appearance and behavior of a celibate prostitute while telling his father the reason for his concern.",
        "questions": [
            "Which section contains Rishyashringa describing the appearance of the celibate woman to Vibhandaka?",
            "Where does Rishyashringa narrate his encounter with the prostitute to his father?"
        ]
    },
    "3.113": {
        "chapter_title": "Rishisringa's visit to Angaraja Lomapada, the king giving his daughter to him, the king welcoming the sage Vibhandaka and the sage being pleased with him.",
        "questions": [
            "Where is Rishyashringa’s marriage to King Lomapada’s daughter described?",
            "Which chapter narrates Lomapada welcoming Sage Vibhandaka and earning his blessing?"
        ]
    },
    "3.114": {
        "chapter_title": "Yudhishthira's journey to Mahendra Parvat via Kaushiki, Gangasagar and Vaitarani River.",
        "questions": [
            "Which chapter narrates Yudhishthira’s pilgrimage through Kaushiki, Ganga Sagar, and Vaitarani?",
            "Where is Yudhishthira’s journey to Mahendra Parvat mentioned?"
        ]
    },
    "3.115": {
        "chapter_title": "In the context of Akritavran's anecdote about Yudhishthira's meeting with Parshuramji, the description of his marriage with Richik Munika Gadhikanya and the birth of Jamadagni by the grace of Bhrigurishi.",
        "questions": [
            "Where is the story of Parashurama’s lineage beginning with Richika and Gadhikanya told?",
            "Which chapter describes Jamadagni’s birth by the grace of Sage Bhrigu?"
        ]
    },
    "3.116": {
        "chapter_title": "Parashurama beheading his mother on his father's orders and bringing her back to life with his blessings; Parashurama killing Kartavirya Arjuna and his sons killing sage Jamadagni.",
        "questions": [
            "Where is Parashurama’s act of beheading his mother and reviving her described?",
            "Which chapter narrates Parashurama’s battle with Kartavirya Arjuna?"
        ]
    },
    "3.117": {
        "chapter_title": "Parashuramji's lamentation for his father and destroying the earth twenty-one times and worship of Parashuramji by Maharaj Yudhishthira.",
        "questions": [
            "Where is Parashurama’s destruction of the Kshatriyas twenty-one times described?",
            "Which section mentions Yudhishthira worshipping Parashurama?"
        ]
    },
    "3.132": {
        "chapter_title": "The story of Ashtavakra's birth and his visit to King Janaka's court",
        "questions": [
            "Which chapter tells the story of Ashtavakra’s birth and deformity?",
            "Where does Ashtavakra first visit King Janaka’s court?"
        ]
    },
    "3.133": {
        "chapter_title": "Aṣṭāvakra's conversation with the gatekeeper and King Janaka",
        "questions": [
            "Where does Ashtavakra converse with the gatekeeper before meeting King Janaka?",
            "Which chapter describes the dialogue between Ashtavakra and Janaka?"
        ]
    },
    "3.134": {
        "chapter_title": "Shastrarth of Bandi and Ashtavakra: Defeat of Bandi and straightening of Ashtavakra's penis by bathing in Samanga.",
        "questions": [
            "Which chapter narrates Ashtavakra’s debate with Bandi in King Janaka’s court?",
            "Where does Ashtavakra regain his normal form after bathing in the Samanga River?"
        ]
    },
    "3.178": {
        "chapter_title": "The mighty Bhimasena killing ferocious animals and being captured by a python",
        "questions": [
            "Where does Bhima fight wild beasts and get caught by a giant serpent?",
            "Which chapter describes Bhima’s encounter with the python in the forest?"
        ]
    },
    "3.179": {
        "chapter_title": "Conversation between Bhimasena and Nahupa in the form of a snake, Bhimasena's worry and Yudhishthira's search for Bhima",
        "questions": [
            "Which chapter features Bhima’s conversation with Nahusha in serpent form?",
            "Where is Yudhishthira shown searching for Bhima after his capture?"
        ]
    },
    "3.180": {
        "chapter_title": "Yudhishthira approaches Bhimasena and answers the questions of Nahusha in the form of a snake",
        "questions": [
            "Which section narrates Yudhishthira’s dialogue with Nahusha in serpent form?",
            "Where does Yudhishthira answer Nahusha’s questions to free Bhima?"
        ]
    },
    "3.181": {
        "chapter_title": "Satisfied with the appropriate answers to his questions from Yudhishthira, Nahusha in the form of a snake released Bhimasena and, due to the effect of his conversation with Yudhishthira, became free from the snake form and went to heaven.",
        "questions": [
            "Where does Nahusha get released from his serpent curse after Yudhishthira’s answers?",
            "Which chapter ends the story of Nahusha’s liberation and Bhima’s release?"
        ]
    }
})


mahabharata_questions.update({
    "3.233": {
        "chapter_title": "Draupadi teaching Satyabhama the duties of a chaste woman",
        "questions": [
            "Which chapter describes Draupadi teaching Satyabhama about the duties of a virtuous wife?",
            "Where is the conversation between Draupadi and Satyabhama on chastity found?"
        ]
    },
    "3.234": {
        "chapter_title": "The way to please your husband - serve your husband with devotion",
        "questions": [
            "Which chapter explains how a wife can please her husband through devoted service?",
            "Where is the teaching on serving one’s husband with devotion described?"
        ]
    },
    "3.235": {
        "chapter_title": "Satyabhama left for Dwarka with Shri Krishna after giving assurance to Draupadi.",
        "questions": [
            "Where does Satyabhama depart for Dwaraka with Shri Krishna?",
            "Which section narrates Satyabhama assuring Draupadi before leaving?"
        ]
    },
    "3.274": {
        "chapter_title": "The birth of Shri Ram and others, and the origin of Kubera and his attainment of wealth.",
        "questions": [
            "Which chapter describes the birth of Shri Ram and the origin of Kubera?",
            "Where is Kubera’s attainment of wealth narrated?"
        ]
    },
    "3.275": {
        "chapter_title": "Origin of Ravana, Kumbhakarna, Vibhishana, Khar and Shurpanakha, penance and attainment of groom and Kubera's curse on Ravana.",
        "questions": [
            "Where is Ravana’s origin and Kubera’s curse on him described?",
            "Which section tells of the birth and penance of Ravana, Kumbhakarna, and Vibhishana?"
        ]
    },
    "3.276": {
        "chapter_title": "The gods went to Brahmaji and prayed to save him from the atrocities of Ravana and with Brahmaji's permission, the gods gave birth to children in bear and monkey wombs and Dundubhi also came in the form of Gandharvi's Manthara.",
        "questions": [
            "Which chapter narrates the gods appealing to Brahma to stop Ravana’s tyranny?",
            "Where is the origin of the monkey and bear warriors described?"
        ]
    },
    "3.277": {
        "chapter_title": "Preparations for the coronation of Shri Ram, Ram's departure to the forest, Bharata's visit to Chitrakoot, destruction of demons like Khar-Dushana by Ram and Ravana's visit to Maricha.",
        "questions": [
            "Which section tells about Ram’s exile and Bharata’s visit to Chitrakoot?",
            "Where is the killing of Khar and Dushan described?"
        ]
    },
    "3.278": {
        "chapter_title": "Killing of deer-like Marichka and kidnapping of Sita",
        "questions": [
            "Where does Ravana abduct Sita after Maricha’s death?",
            "Which chapter narrates the killing of Maricha disguised as a deer?"
        ]
    },
    "3.279": {
        "chapter_title": "Killing of Jatayu by Ravana, his funeral rites by Shri Ram, killing of Kabandha and his abduction by him",
        "questions": [
            "Which section describes the killing of Jatayu and his funeral by Shri Ram?",
            "Where does Kabandha’s story and his killing by Ram appear?"
        ]
    },
    "3.280": {
        "chapter_title": "The friendship between Rama and Sugreeva, the battle between Vali and Sugreeva, the killing of Vali by Shri Ram and Trijata's assurance to Sita who was frightened by the demons in the Ashoka Vatika of Lanka.",
        "questions": [
            "Which chapter narrates the alliance between Rama and Sugriva and the killing of Vali?",
            "Where is Trijata comforting Sita in Ashok Vatika described?"
        ]
    },
    "3.281": {
        "chapter_title": "Dialogue between Ravana and Sita",
        "questions": [
            "Where does the dialogue between Ravana and Sita take place in Lanka?",
            "Which chapter records Ravana’s persuasion and Sita’s steadfast refusal?"
        ]
    },
    "3.282": {
        "chapter_title": "Shri Ram's anger on Sugriva, Sugriva sending monkeys in search of Sita and Shri Hanumanji requesting the account of his journey to Lanka after returning.",
        "questions": [
            "Which chapter narrates Hanuman’s return from Lanka and recounting his journey?",
            "Where does Sugriva send the monkey army to search for Sita?"
        ]
    },
    "3.283": {
        "chapter_title": "The organization of the monkey army, the construction of the bridge, the coronation of Vibhishana, the entry of the army into the borders of Lanka, and the sending of Angada as an emissary to Ravana.",
        "questions": [
            "Which section describes the building of the bridge to Lanka?",
            "Where is Angada’s embassy to Ravana mentioned?"
        ]
    },
    "3.284": {
        "chapter_title": "Angada goes to Ravana and returns with Ram's message and the fierce battle between the demons and the monkeys",
        "questions": [
            "Which chapter depicts Angada delivering Ram’s message to Ravana?",
            "Where is the battle between the Vanaras and Rakshasas narrated?"
        ]
    }
})
mahabharata_questions.update({
    "3.224": {
        "chapter_title": "Swahaka's union with Agni in the form of sages' wives",
        "questions": [
            "Which chapter narrates Swaha’s union with Agni taking the form of sages’ wives?",
            "Where is the story of Agni’s union with Swaha described?"
        ]
    },
    "3.225": {
        "chapter_title": "Creation of Skanda and disintegration of mountains like Krauncha",
        "questions": [
            "Which chapter describes the birth of Skanda (Kartikeya)?",
            "Where is the destruction of mountains like Krauncha by Skanda mentioned?"
        ]
    },
    "3.226": {
        "chapter_title": "Vishwamitra performing thirteen rites like Jatakarma etc. for Skanda and the sages not accepting their wives even after Vishwamitra's persuasion and the protection of the child Skanda by Agnidev etc.",
        "questions": [
            "Where is Vishwamitra performing the sacred rites for Skanda described?",
            "Which chapter mentions Agnidev protecting the child Skanda?"
        ]
    },
    "3.227": {
        "chapter_title": "Skanda gave protection to the gods including Indra who had come to seek refuge after being defeated",
        "questions": [
            "Where does Skanda grant protection to Indra and the other gods after their defeat?",
            "Which section narrates the gods seeking refuge in Skanda?"
        ]
    },
    "3.229": {
        "chapter_title": "Skandaka's conversation with Indra, his consecration to the post of Devasenapati and his marriage with Devasena",
        "questions": [
            "Which chapter tells of Skanda being made the commander of the gods?",
            "Where is Skanda’s marriage to Devasena described?"
        ]
    },
    "3.230": {
        "chapter_title": "Description of the Krittikas getting their place in the constellations and the various planets that cause trouble to humans",
        "questions": [
            "Which chapter explains how the Krittikas became stars in the sky?",
            "Where is the description of planets causing troubles to humans found?"
        ]
    },
    "3.231": {
        "chapter_title": "Skanda's hospitality to Swahadevi, Skanda's journey with Rudradev and the gods to Bhadravat, battle between gods, killing of Mahishasura and praise of Skanda",
        "questions": [
            "Where is Skanda’s battle with Mahishasura narrated?",
            "Which chapter mentions Skanda’s journey with Rudra and the gods?"
        ]
    },
    "3.232": {
        "chapter_title": "Description of the famous names of Kartikeya and their praise",
        "questions": [
            "Which section lists the many names and titles of Kartikeya?",
            "Where is the praise and glorification of Kartikeya described?"
        ]
    }
})

mahabharata_questions.update({
    "3.285": {
        "chapter_title": "Duel between the armies of Shri Ram and Ravana",
        "questions": [
            "Which chapter narrates the great battle between Rama and Ravana’s armies?",
            "Where is the clash of the Vanara and Rakshasa forces described?"
        ]
    },
    "3.286": {
        "chapter_title": "Ravana, saddened by the killing of Prahastha and Dhumraksha, awakens Kumbhakarna and sends him into battle.",
        "questions": [
            "Where does Ravana awaken Kumbhakarna for battle?",
            "Which section describes Ravana’s grief over Prahastha and Dhumraksha’s deaths?"
        ]
    },
    "3.287": {
        "chapter_title": "Killing of Kumbhakarna, Vajravega and Pramathika",
        "questions": [
            "Which chapter depicts the killing of Kumbhakarna by Shri Ram?",
            "Where are Vajravega and Pramathika slain in battle?"
        ]
    },
    "3.288": {
        "chapter_title": "Indrajit's illusory war and Shri Ram and Lakshman's unconsciousness",
        "questions": [
            "Where does Indrajit use illusion in battle against Rama and Lakshmana?",
            "Which chapter narrates Rama and Lakshmana becoming unconscious in Indrajit’s attack?"
        ]
    },
    "3.289": {
        "chapter_title": "Shri Ram and Lakshman becoming conscious and washing their eyes along with the main monkeys with the water invited by Kubera, Lakshman killing Indrajit and Avindhya stopping Ravana who was ready to kill Sita.",
        "questions": [
            "Which chapter describes Lakshmana killing Indrajit?",
            "Where does Avindhya restrain Ravana from killing Sita?"
        ]
    },
    "3.290": {
        "chapter_title": "The battle between Rama and Ravana and the killing of Ravana",
        "questions": [
            "Which chapter recounts the final duel between Rama and Ravana?",
            "Where is Ravana’s death at Rama’s hands described?"
        ]
    },
    "3.291": {
        "chapter_title": "Shri Ram's doubts about Sita, the gods' support for Sita's purification, Shri Ram's departure from Lanka with his army and reaching Ayodhya via Kishkindha, meeting Bharata and being anointed king.",
        "questions": [
            "Which chapter narrates Sita’s trial by fire and divine vindication?",
            "Where does Rama return to Ayodhya and reunite with Bharata?"
        ]
    },
    "3.292": {
        "chapter_title": "Markandeya's assurance to King Yudhishthira",
        "questions": [
            "Where does Sage Markandeya console or reassure Yudhishthira?",
            "Which section contains Markandeya’s counsel to Yudhishthira during exile?"
        ]
    },
    "3.293": {
        "chapter_title": "King Aswapati was blessed with a daughter named Savitri by Goddess Savitri and travelled to various countries to find Savitri as his wife.",
        "questions": [
            "Which chapter tells of King Aswapati’s boon of a daughter Savitri?",
            "Where is Aswapati’s search for a suitable husband for Savitri described?"
        ]
    },
    "3.294": {
        "chapter_title": "Savitrika's determination to marry Satyavan",
        "questions": [
            "Which chapter narrates Savitri’s decision to marry Satyavan?",
            "Where does Savitri express her firm resolve to wed Satyavan despite warnings?"
        ]
    },
    "3.295": {
        "chapter_title": "The marriage of Satyavan and Savitri and satisfying everyone with his services",
        "questions": [
            "Which chapter narrates the wedding of Savitri and Satyavan?",
            "Where is the account of Savitri’s devoted service to her family found?"
        ]
    },
    "3.296": {
        "chapter_title": "Savitri's vow of fasting and her going to the forest with Satyavan after taking permission from her parents-in-law and husband.",
        "questions": [
            "Which chapter depicts Savitri’s vow and her journey to the forest with Satyavan?",
            "Where is Savitri’s act of fasting before accompanying Satyavan described?"
        ]
    },
    "3.297": {
        "chapter_title": "The conversation between Savitri and Yama, Yama being pleased, grants Savitri many boons and even brings the dead Satyavan back to life, and the conversation between Satyavan and Savitri and their departure for the ashram.",
        "questions": [
            "Which chapter contains the dialogue between Savitri and Yama?",
            "Where does Yama restore Satyavan’s life and bless Savitri?"
        ]
    },
    "3.298": {
        "chapter_title": "King Dyumatsen's concern for Satyavan along with his wife, the sages' assurance to him, the arrival of Savitri and Satyavan and narrating the details of getting the groom by throwing light on the reason behind Savitri's late arrival.",
        "questions": [
            "Which chapter describes Dyumatsena’s concern for his son Satyavan?",
            "Where does Savitri explain the cause of her delayed return with Satyavan?"
        ]
    },
    "3.299": {
        "chapter_title": "Coronation of King Dyumtsen at the request of the people of Shalva country and Savitri getting hundred sons and hundred brothers (Kundalaharan Parva).",
        "questions": [
            "Where does Dyumatsena regain his kingdom with the people’s request?",
            "Which chapter describes the blessings of Savitri’s hundred sons and brothers?"
        ]
    },
    "3.300": {
        "chapter_title": "Surya appeared to Karna in his dream and warned him not to give the earrings and armor to Indra and Karna insisted on giving him the earrings and armor.",
        "questions": [
            "Which chapter describes Surya warning Karna about Indra’s visit?",
            "Where does Karna insist on giving away his divine armor and earrings?"
        ]
    }
})

mahabharata_questions.update({
    "3.301": {
        "chapter_title": "Surya admonishing Karna and ordering him not to give the ring to Indra",
        "questions": [
            "Which chapter describes Surya warning Karna against giving his earrings to Indra?",
            "Where does Surya advise Karna to keep his divine armor and earrings?"
        ]
    },
    "3.302": {
        "chapter_title": "Surya-Karna dialogue, as per Surya's orders, Karna decides to give him the earrings and armor only after taking power from Indra.",
        "questions": [
            "Which chapter narrates the dialogue between Surya and Karna?",
            "Where does Karna resolve to part with his armor only after gaining a boon from Indra?"
        ]
    },
    "3.303": {
        "chapter_title": "Arrival of Maharishi Durvasa at Kuntibhoja's place and the king giving necessary instructions to Pritha for his service.",
        "questions": [
            "Where does Sage Durvasa arrive at Kuntibhoja’s court?",
            "Which chapter describes Kuntibhoja assigning Pritha (Kunti) to serve Durvasa?"
        ]
    },
    "3.304": {
        "chapter_title": "Kunti's conversation with her father and her service to the Brahmin",
        "questions": [
            "Which chapter narrates Kunti’s conversation with her father about Durvasa’s visit?",
            "Where is Kunti’s service to the Brahmin guest described?"
        ]
    },
    "3.305": {
        "chapter_title": "Satisfied with Kunti's service, the ascetic Brahmin teaches her the mantra",
        "questions": [
            "Where does Durvasa teach Kunti the divine mantra as a reward for her service?",
            "Which section describes the Brahmin granting Kunti a boon for her devotion?"
        ]
    },
    "3.306": {
        "chapter_title": "Kunti's invocation of the Sun God and Kunti-Sun dialogue",
        "questions": [
            "Which chapter describes Kunti invoking the Sun God through the mantra?",
            "Where is the dialogue between Kunti and Surya narrated?"
        ]
    },
    "3.307": {
        "chapter_title": "Surya impregnated Kunti in her womb",
        "questions": [
            "Where does Surya bless Kunti and cause her to conceive Karna?",
            "Which chapter narrates the divine conception of Karna by Kunti and Surya?"
        ]
    },
    "3.308": {
        "chapter_title": "Karna is born, Kunti puts him in a box and throws it into the water and laments.",
        "questions": [
            "Which chapter tells of Karna’s birth and Kunti setting him afloat in the river?",
            "Where does Kunti grieve after abandoning her infant son Karna?"
        ]
    },
    "3.309": {
        "chapter_title": "The birth of a child Karna to Adhiratha and his wife Radha, his upbringing by Radha, his education in Hastinapur and Indra's arrival to Karna.",
        "questions": [
            "Which chapter describes Karna’s adoption by Adhiratha and Radha?",
            "Where is Indra’s arrival to meet Karna mentioned?"
        ]
    },
    "3.310": {
        "chapter_title": "Indra giving Karna infallible powers and in return taking his armour and earrings",
        "questions": [
            "Where does Indra receive Karna’s divine armor and earrings in exchange for a boon?",
            "Which chapter narrates Indra blessing Karna with the Vasavi Shakti weapon?"
        ]
    },
    "3.311": {
        "chapter_title": "The Pandavas chase the deer to find the Brahmin's firewood and the churning wood and feel sad.",
        "questions": [
            "Which chapter narrates the Pandavas chasing a deer that stole the Brahmin’s firewood?",
            "Where is the incident leading to the Yaksha’s lake described?"
        ]
    },
    "3.312": {
        "chapter_title": "Nakula and the other four brothers, who had gone to fetch water, fell unconscious on the bank of the lake.",
        "questions": [
            "Where do the Pandavas fall unconscious one after another by the lake?",
            "Which section precedes Yudhishthira’s encounter with the Yaksha?"
        ]
    },
    "3.313": {
        "chapter_title": "The question and answer between Yaksha and Yudhishthira and the Yaksha being satisfied with Yudhishthira's answer giving the boon of life to all four brothers.",
        "questions": [
            "Which chapter contains the dialogue between Yaksha and Yudhishthira?",
            "Where does Yaksha restore the lives of the Pandavas after being pleased with Yudhishthira’s answers?",
            "Which section includes Yudhishthira’s famous philosophical responses to Yaksha?"
        ]
    }
})

# %% [markdown]
# ###

# %%
len(mahabharata_questions)
# Out:
# 182

# %%
import json

with open('mahabharata_questions.json', 'w') as f:
    json.dump(mahabharata_questions, f, indent=4)

# %%
import numpy as np
import pickle
import faiss
import pandas as pd
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

class EmbeddingSearchEvaluator:
    def __init__(self,
                 model_name="sentence-transformers/all-mpnet-base-v2",
                 emb_path="embeddings.npy",
                 ids_path="doc_ids.pkl"):
        # Load model and data
        self.model = SentenceTransformer(model_name)
        self.embeddings = np.load(emb_path)
        with open(ids_path, "rb") as f:
            self.doc_ids = pickle.load(f)
        print(f"Loaded {len(self.embeddings)} embeddings.")

        # Normalize for cosine/dot similarity
        faiss.normalize_L2(self.embeddings)

        # Build FAISS index
        dim = self.embeddings.shape[1]
        self.index = faiss.IndexFlatIP(dim)
        self.index.add(self.embeddings)

    def search(self, query, top_k=3):
        """Search for top_k most similar documents for a query string."""
        query_vec = self.model.encode([query], convert_to_numpy=True)
        faiss.normalize_L2(query_vec)
        D, I = self.index.search(query_vec, k=top_k)
        results = [
            {"rank": r + 1,
             "score": float(D[0][r]),
             "doc_id": self.doc_ids[I[0][r]]}
            for r in range(top_k)
        ]
        return results

    def evaluate_questions(self, questions_dict, top_k=3):
        """
        questions_dict format:
        {
            "3.313": {"chapter_title": "...", "questions": ["Q1", "Q2", ...]},
            "3.200": {...},
            ...
        }
        """
        rows = []
        for true_id, entry in tqdm(questions_dict.items()):
            for q in entry.get("questions", []):
                results = self.search(q, top_k=top_k)
                retrieved_ids = [r["doc_id"] for r in results]
                correct = true_id in retrieved_ids
                rank = retrieved_ids.index(true_id) + 1 if correct else None
                rows.append({
                    "query": q,
                    "ground_truth": true_id,
                    "top_ids": retrieved_ids,
                    "correct": correct,
                    "rank_of_correct": rank
                })
        self.results_df = pd.DataFrame(rows)
        return self.results_df

    def accuracy(self):
        """Compute Top-k retrieval accuracy."""
        if not hasattr(self, "results_df"):
            raise ValueError("Run evaluate_questions() first.")
        return self.results_df["correct"].mean()

    def save_results(self, path="retrieval_results.csv"):
        """Save results as CSV."""
        if hasattr(self, "results_df"):
            self.results_df.to_csv(path, index=False)
            print(f"✅ Saved results to {path}")
        else:
            print("No results to save.")

# %%
# Initialize evaluator
evaluator = EmbeddingSearchEvaluator(
    model_name="sentence-transformers/all-mpnet-base-v2",
    emb_path="embeddings.npy",
    ids_path="doc_ids.pkl"
)
# Evaluate
df_results = evaluator.evaluate_questions(mahabharata_questions, top_k=3)
print(df_results.head())

# Accuracy
print("Top-3 accuracy:", evaluator.accuracy())

# Save to CSV
evaluator.save_results("yaksha_retrieval_results.csv")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loaded 2108 embeddings.
# 100%|██████████| 182/182 [01:02<00:00,  2.93it/s]
#                                                query ground_truth  \
# 0  What is the main premise and scope of the Maha...          1.1
# 1  Which topics are briefly listed or summarized ...          1.1
# 2  What glories or benefits are said to come from...          1.1
# ...
